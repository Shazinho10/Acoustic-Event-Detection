# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/capuuchan_audio_classification'
# Out:
# /content/drive/MyDrive/capuuchan_audio_classification

# %%
import numpy as np
import pandas as pd
import os
import librosa
import librosa.display
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras import Sequential, layers, models
from sklearn.model_selection import train_test_split

# %%
x_train = np.load('/content/drive/MyDrive/capuuchan_audio_classification/training_testing_arrays_saved/x_train.npy')
x_test = np.load('/content/drive/MyDrive/capuuchan_audio_classification/training_testing_arrays_saved/x_test.npy')
y_train = np.load('/content/drive/MyDrive/capuuchan_audio_classification/training_testing_arrays_saved/y_train.npy')
y_test = np.load('/content/drive/MyDrive/capuuchan_audio_classification/training_testing_arrays_saved/y_test.npy')

# %%
x_train_exp = np.expand_dims(x_train, axis=-1)
x_test_exp = np.expand_dims(x_test, axis=-1)

# %%
x_test_exp.shape
# Out:
# (104, 100, 216, 1)

# %%
model = models.Sequential([
    layers.Conv2D(70, kernel_size=(2,2), activation='relu', padding='same'),
    layers.MaxPooling2D((2,2)), 

    layers.Conv2D(50, kernel_size=(2,2), activation='relu', padding='same'),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(40, kernel_size=(2,2), activation='relu', padding='same'),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(10, kernel_size=(2,2), activation='relu', padding='same'),
    layers.MaxPooling2D((2,2)),
    
    
    layers.Flatten(),
    layers.Dense(500, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(300, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(150, activation='relu'),
    layers.Dense(120, activation='relu'),
    layers.Dense(100, activation='relu'),
    layers.Dense(80, activation='relu'),
    layers.Dense(50, activation='relu'),
    layers.Dense(20, activation='relu'),
    layers.Dense(1, activation='sigmoid')
    
])


model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train_exp, y_train, epochs=8, batch_size=20, validation_data=(x_test_exp, y_test))
# Out:
# Epoch 1/8
# 32/32 [==============================] - 2s 35ms/step - loss: 0.4773 - accuracy: 0.7812 - val_loss: 0.4599 - val_accuracy: 0.9135
# Epoch 2/8
# 32/32 [==============================] - 1s 25ms/step - loss: 0.2595 - accuracy: 0.9089 - val_loss: 0.1640 - val_accuracy: 0.9904
# Epoch 3/8
# 32/32 [==============================] - 1s 25ms/step - loss: 0.0897 - accuracy: 0.9712 - val_loss: 0.1041 - val_accuracy: 0.9808
# Epoch 4/8
# 32/32 [==============================] - 1s 25ms/step - loss: 0.0371 - accuracy: 0.9904 - val_loss: 0.0593 - val_accuracy: 0.9904
# Epoch 5/8
# 32/32 [==============================] - 1s 25ms/step - loss: 0.0253 - accuracy: 0.9904 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 6/8
# 32/32 [==============================] - 1s 25ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.3303 - val_accuracy: 0.9615
# Epoch 7/8
# 32/32 [==============================] - 1s 25ms/step - loss: 0.0175 - accuracy: 0.9952 - val_loss: 0.0626 - val_accuracy: 0.9808
# Epoch 8/8
# 32/32 [==============================] - 1s 25ms/step - loss: 3.1884e-04 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 0.9808

# %%
if os.path.isfile('audio_model.h5') is False:
  model.save('audio_model.h5')
